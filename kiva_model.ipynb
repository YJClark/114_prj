# %%
from gurobipy import *

# 創建模型
m = Model("Robot and Cargo Path Planning")

# 定義網格大小和時間上限
grid_size, T, num_robots, num_cargos = 3, 8, 7, 7

# 變量
x = m.addVars(num_robots, grid_size, grid_size, T+1, vtype=GRB.BINARY, name="robot")  # 機器人的位置變量
c = m.addVars(num_cargos, grid_size, grid_size, T+1, vtype=GRB.BINARY, name="cargo")  # 貨物的位置變量
z = m.addVars(num_robots, num_cargos, T+1, vtype=GRB.BINARY, name="carrying")         # 機器人搬運貨物的變量
y = m.addVars(num_cargos, T+1, vtype=GRB.BINARY, name="finish")                       # 貨物到達終點的變量
#機器人移動方向變量
move = m.addVars(num_robots, grid_size, grid_size, 4, T, vtype=GRB.BINARY, name="move")  # 0: 左, 1: 右, 2: 上, 3: 下
#最慢到達貨物的到達時間
max_arrival_time = m.addVar(vtype=GRB.INTEGER, name="max_arrival_time")


# 權重參數
alpha = 0.001  
# 設定初始位置和目標位置
initial_positions = [(0, 2, 2), (1, 0, 2),(2 ,1, 0), (3, 0, 0), (4, 0, 1), (5, 1, 1), (6, 2, 0)]  # 機器人的初始位置
cargo_init_pos = [(0, 2, 2), (1, 0, 2),(2 ,1, 0), (3, 0, 0), (4, 0, 1), (5, 1, 1), (6, 2, 0)]  # 貨物的初始位置
cargo_goal_pos = [(0, 0, 2), (1, 1, 0),(2 ,1, 2), (None, None, None), (None, None, None), (None, None, None), (None, None, None)]  # 貨物的目標位置，(None, None, None) 表示沒有固定終點

# 目標函數，最小化貨物的到達時間和所有機器人的移動總次數
m.setObjective(
    max_arrival_time + 
    alpha * quicksum(x[r, i, j, t] * (1 - x[r, i, j, t-1]) 
                     for r in range(num_robots) 
                     for i in range(grid_size) 
                     for j in range(grid_size) 
                     for t in range(1, T+1)),
    GRB.MINIMIZE
)

# 最慢到達貨物的到達時間
for c_idx in range(num_cargos):
    if cargo_goal_pos[c_idx][0] is not None:
        for t in range(1, T+1):
            m.addConstr(max_arrival_time >= t * (y[c_idx, t] - y[c_idx, t-1]))


for r, i, j in initial_positions:
    m.addConstr(x[r, i, j, 0] == 1)

# 貨物的初始位置
for c_idx, i, j in cargo_init_pos:
    m.addConstr(c[c_idx, i, j, 0] == 1)

# 貨物的目標位置（只對有固定終點的貨物設置約束）
for c_idx, goal in enumerate(cargo_goal_pos):
    if goal[0] is not None:
        _, i, j = goal
        m.addConstr(y[c_idx, T] == 1)  # 確保在最後時刻 T 時，有固定終點的貨物都到達終點
        for t in range(1, T+1):
            m.addConstr(y[c_idx, t] <= c[c_idx, i, j, t])
            m.addConstr(y[c_idx, t] >= y[c_idx, t-1])  # 一旦到達終點，狀態保持到達

# 每個格子在每個時刻只能有一個機器人或貨物
for t in range(T+1):
    for i in range(grid_size):
        for j in range(grid_size):
            m.addConstr(quicksum(x[r, i, j, t] for r in range(num_robots)) <= 1)  # 機器人
            m.addConstr(quicksum(c[cargo, i, j, t] for cargo in range(num_cargos)) <= 1)  # 貨物

# 機器人和貨物在每個時刻只會在一個格子
for t in range(T+1):
    for r in range(num_robots):
        m.addConstr(quicksum(x[r, i, j, t] for i in range(grid_size) for j in range(grid_size)) == 1)
    for cargo in range(num_cargos):
        m.addConstr(quicksum(c[cargo, i, j, t] for i in range(grid_size) for j in range(grid_size)) == 1)

# 機器人和貨物的移動
for t in range(T):
    for r in range(num_robots):  #機器人只能在相鄰位置之間移動
        for i in range(grid_size):
            for j in range(grid_size):
                m.addConstr(x[r, i, j, t+1] <= x[r, i, j, t] + 
                            quicksum(x[r, i1, j1, t] 
                                     for i1, j1 in [(i-1, j), (i+1, j), (i, j-1), (i, j+1)]
                                     if 0 <= i1 < grid_size and 0 <= j1 < grid_size))

    for cargo in range(num_cargos):   #貨物的移動需要由機器人來完成，並且只能在相鄰位置之間移動
        for i in range(grid_size):
            for j in range(grid_size):
                m.addConstr(c[cargo, i, j, t+1] <= c[cargo, i, j, t] + 
                            quicksum(z[r, cargo, t] * x[r, i, j, t+1] for r in range(num_robots)))

# 機器人搬運貨物的約束
for t in range(T):
    for r in range(num_robots):
        for cargo in range(num_cargos):
            m.addConstr(z[r, cargo, t] <= quicksum(x[r, i, j, t] * c[cargo, i, j, t] 
                                     for i in range(grid_size) for j in range(grid_size)))

# 機器人和貨物搬運數量的限制
for t in range(T+1):
    for r in range(num_robots):
        m.addConstr(quicksum(z[r, cargo, t] for cargo in range(num_cargos)) <= 1)  # 每個機器人同時只能搬運一個貨物
    for cargo in range(num_cargos):
        m.addConstr(quicksum(z[r, cargo, t] for r in range(num_robots)) <= 1)  # 每個貨物同時只能被一個機器人搬運

# 機器人的移動和位置變化
for t in range(T):
    for r in range(num_robots):
        for i in range(grid_size):
            for j in range(grid_size):
                # 左移
                if j > 0:
                    m.addConstr(move[r, i, j, 0, t] == x[r, i, j, t] * x[r, i, j-1, t+1])
                # 右移
                if j < grid_size - 1:
                    m.addConstr(move[r, i, j, 1, t] == x[r, i, j, t] * x[r, i, j+1, t+1])
                # 上移
                if i > 0:
                    m.addConstr(move[r, i, j, 2, t] == x[r, i, j, t] * x[r, i-1, j, t+1])
                # 下移
                if i < grid_size - 1:
                    m.addConstr(move[r, i, j, 3, t] == x[r, i, j, t] * x[r, i+1, j, t+1])
                
                
# 避免同一時間內格點的水平移入和垂直移出同時發生，或反之
for t in range(T):
    for i in range(grid_size):
        for j in range(grid_size):
            # 水平移入 (從左邊或右邊進入)
            horizontal_in = quicksum(move[r, i, j, 0, t] for r in range(num_robots)) + \
                            quicksum(move[r, i, j, 1, t] for r in range(num_robots))
            
            # 水平移出 (移到左邊或右邊)
            horizontal_out = quicksum(move[r, i, j-1, 1, t] for r in range(num_robots) if j > 0) + \
                             quicksum(move[r, i, j+1, 0, t] for r in range(num_robots) if j < grid_size - 1)

            # 垂直移入 (從上方或下方進入)
            vertical_in = quicksum(move[r, i, j, 2, t] for r in range(num_robots)) + \
                          quicksum(move[r, i, j, 3, t] for r in range(num_robots))

            # 垂直移出 (移到上方或下方)
            vertical_out = quicksum(move[r, i-1, j, 3, t] for r in range(num_robots) if i > 0) + \
                           quicksum(move[r, i+1, j, 2, t] for r in range(num_robots) if i < grid_size - 1)

            # 避免水平移入與垂直移出同時發生
            m.addConstr(horizontal_in + vertical_out <= 1)
            
            # 避免垂直移入與水平移出同時發生
            m.addConstr(vertical_in + horizontal_out <= 1)

# 避免機器人直接互换位置
for t in range(T):
    for i in range(grid_size):
        for j in range(grid_size):
            for di, dj in [(0, 1), (1, 0)]:  
                if i + di < grid_size and j + dj < grid_size:
                    m.addConstr(quicksum(x[r, i, j, t] * x[r, i+di, j+dj, t+1] for r in range(num_robots)) +
                                quicksum(x[r, i+di, j+dj, t] * x[r, i, j, t+1] for r in range(num_robots)) <= 1)

# 機器人轉向移動限制
for t in range(T-1):
    for r in range(num_robots):
        for i in range(grid_size):
            for j in range(grid_size):
                # 如果在t時刻垂直移動（上移或下移），則在t+1時刻不能水平移動
                vertical_move_t = move[r, i, j, 2, t] + move[r, i, j, 3, t]
                horizontal_move_t1 = quicksum(move[r, i1, j1, d, t+1] 
                                              for i1 in range(grid_size) 
                                              for j1 in range(grid_size) 
                                              for d in [0, 1])  # 0: 左, 1: 右
                m.addConstr(vertical_move_t + horizontal_move_t1 <= 1)

                # 如果在t時刻水平移動（左移或右移），則在t+1時刻不能垂直移動
                horizontal_move_t = move[r, i, j, 0, t] + move[r, i, j, 1, t]
                vertical_move_t1 = quicksum(move[r, i1, j1, d, t+1] 
                                            for i1 in range(grid_size) 
                                            for j1 in range(grid_size) 
                                            for d in [2, 3])  # 2: 上, 3: 下
                m.addConstr(horizontal_move_t + vertical_move_t1 <= 1)


m.setParam('MIPFocus', 2) 
m.optimize()


# 輸出結果
if m.status == GRB.OPTIMAL:
    for t in range(T+1):
        print(f"time period {t}")
        
        grid = [[0 for _ in range(grid_size)] for _ in range(grid_size)]
        
        for r in range(num_robots):
            for i in range(grid_size):
                for j in range(grid_size):
                    if x[r, i, j, t].x > 0.5:
                        grid[i][j] = r + 1  
        
        for row in grid:
            print("|", end=" ")
            for cell in row:
                print(f"{cell:2}", end=" ")
            print("|")
        print()  
        for r in range(num_robots):
            robot_pos = [(i+1, j+1) for i in range(grid_size) for j in range(grid_size) if x[r, i, j, t].x > 0.5]
            print(f"機器人{r+1}在 {robot_pos}", end="")
            
            carrying = [cargo+1 for cargo in range(num_cargos) if z[r, cargo, t].x > 0.5]
            if carrying:
                print(f", 正在搬運貨物{carrying[0]}", end="")
            print()
        # 貨物位置資訊
        for cargo in range(num_cargos):
            cargo_pos = [(i+1, j+1) for i in range(grid_size) for j in range(grid_size) if c[cargo, i, j, t].x > 0.5]
            if cargo_goal_pos[cargo][0] is not None:
                _, goal_i, goal_j = cargo_goal_pos[cargo]
                goal_i, goal_j = goal_i + 1, goal_j + 1
                if cargo_pos == [(goal_i, goal_j)]:
                    print(f"貨物{cargo+1}在 {cargo_pos}, 貨物已到達目標位置")
                else:
                    print(f"貨物{cargo+1}在 {cargo_pos}")
            else:
                print(f"貨物{cargo+1}在 {cargo_pos} (無固定目標位置)")
        print() 
else:
    print("無法找到解")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-10
# Set parameter MIPFocus to value 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2033 rows, 3655 columns and 26687 nonzeros
# Model fingerprint: 0x112c8b43
# Model has 504 quadratic objective terms
# Model has 2336 quadratic constraints
# Variable types: 0 continuous, 3655 integer (3654 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e-03, 1e+00]
#   QObjective range [2e-03, 2e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#   QRHS range       [1e+00, 1e+00]
# Presolve removed 1040 rows and 1524 columns
# Presolve time: 0.08s
# Presolved: 16180 rows, 8362 columns, 44527 nonzeros
# Variable types: 0 continuous, 8362 integer (8361 binary)
# Root relaxation presolved: 8137 rows, 4708 columns, 37194 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.7610000e+00   6.587500e+02   0.000000e+00      8s
#     2633    4.1911179e+00   0.000000e+00   0.000000e+00      8s
#     2633    4.1911179e+00   0.000000e+00   0.000000e+00      8s
#
# Root relaxation: objective 4.191118e+00, 2633 iterations, 0.19 seconds (0.12 work units)
# Total elapsed time = 8.09s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.19112    0  361          -    4.19112      -     -    8s
#      0     0    5.00239    0  304          -    5.00239      -     -    9s
#      0     0    5.00364    0  314          -    5.00364      -     -    9s
#      0     0    5.00376    0  505          -    5.00376      -     -    9s
#      0     0    5.00400    0  542          -    5.00400      -     -   11s
#      0     0    5.00402    0  327          -    5.00402      -     -   11s
#      0     0    5.00405    0  357          -    5.00405      -     -   12s
#      0     0    5.00405    0  334          -    5.00405      -     -   13s
#      0     2    5.00405    0  330          -    5.00405      -     -   14s
#     15    20    5.00497    4  341          -    5.00497      -   427   15s
#    184   118    7.01146   40  641          -    5.00497      -   416   20s
#    378   214    7.00394   13  259          -    5.00545      -   415   25s
#    641   387    6.01253   29  365          -    5.00553      -   400   30s
#    818   501    5.04157   20  477          -    5.00583      -   425   35s
#   1109   707    5.00928    9  333          -    5.00597      -   426   40s
#   1428   847    6.01150   18 2317          -    5.00613      -   420   47s
#   1431   849    6.00576   18  520          -    5.00613      -   419   50s
#   1436   852    5.00742    7  473          -    5.00613      -   418   55s
#   1440   855    5.99950   13  481          -    5.00613      -   416   60s
#   1444   858    6.00911   22  582          -    6.00119      -   415   67s
#   1446   859    8.01147   51  832          -    6.00212      -   415   71s
#   1448   860    6.00261   17  599          -    6.00261      -   414   76s
#   1450   862    6.00270   17  676          -    6.00270      -   414   80s
#   1454   864    6.01133   39  585          -    6.00288      -   412   86s
#   1458   867    6.01260   32  645          -    6.00291      -   411   91s
#   1462   870    6.00992   27  625          -    6.00301      -   410   97s
#   1464   871    6.99863   37  729          -    6.00305      -   410  100s
#   1467   873    6.00984   25  798          -    6.00318      -   409  105s
#   1470   875    7.01480   27  735          -    6.00320      -   408  112s
#   1472   876    6.00613   12  924          -    6.00330      -   407  116s
#   1474   878    6.00331   10 1081          -    6.00331      -   407  120s
#   1478   880    7.01069   32  938          -    6.00331      -   406  125s
#   1481   882    6.00331   10  972          -    6.00331      -   405  130s
#   1488   888    8.01347   56 2311          -    6.00397      -   458  137s
#   1490   889    6.00935   28  331          -    6.00397      -   458  143s
#   1492   891    6.00397    4  833          -    6.00397      -   457  147s
#   1494   892    6.00857   19  847          -    6.00397      -   456  152s
#   1496   893    6.99643   19  803          -    6.00397      -   456  156s
#   1499   895    6.00397   16  903          -    6.00397      -   455  160s
#   1504   899    6.00397   18  892          -    6.00397      -   453  167s
#   1506   900    6.00397    5  859          -    6.00397      -   453  170s
#   1509   902    6.00400   14 1013          -    6.00397      -   452  175s
#   1513   905    7.00844   35  812          -    6.00397      -   451  181s
#   1524   917    6.00625   29  249          -    6.00411      -   506  185s
#   1540   920    6.00700   31  353          -    6.00433      -   535  190s
#   1548   924    6.00603   32  449          -    6.00436      -   554  196s
#   1566   936    6.00451   34  357          -    6.00451      -   571  200s
#   1586   942    6.00601   37  326          -    6.00453      -   598  205s
#   1620   947    6.00684   41  392          -    6.00453      -   628  210s
#   1646   950    6.00854   43  525          -    6.00453      -   656  216s
#   1666   945    6.01332   46  387          -    6.00453      -   677  220s
#   1677   940    6.01456   48  319          -    6.00453      -   692  239s
#   1689   943    7.01167   49  288          -    6.00453      -   707  240s
#   1724   938    7.00850   53  287          -    6.00453      -   734  246s
#   1787   940    8.01341   63  313          -    6.00543      -   764  253s
#   1814   941    6.00820   36  384          -    6.00543      -   777  255s
#   1850   933    6.26175   39  337          -    6.00543      -   800  260s
#   1868   927    7.01046   40  350          -    6.00543      -   815  265s
#   1913   929    6.01030   31  487          -    6.00588      -   849  272s
#   1938   932 infeasible   34               -    6.00588      -   881  276s
#   1988   932 infeasible   44               -    6.00596      -   893  280s
#   2053   936    6.00724   41  475          -    6.00603      -   931  288s
#   2089   935    6.01524   45  428          -    6.00603      -   950  293s
#   2122   941    7.01600   47  242          -    6.00603      -   978  299s
#   2164   942    7.01759   51  451          -    6.00607      -   997  303s
#   2217   946    7.00670   36  633          -    6.00607      -  1011  307s
#   2251   954    7.00895   40  621          -    6.00607      -  1028  312s
#   2283   945    7.00943   40  612          -    6.00607      -  1043  317s
#   2308   939 infeasible   42               -    6.00607      -  1068  324s
#   2350   926 infeasible   43               -    6.00607      -  1088  329s
#   2382   923    8.00522   33  330          -    6.00607      -  1107  333s
#   2419   925 infeasible   41               -    6.00640      -  1127  338s
#   2459   920    6.00883   51  404          -    6.00658      -  1140  365s
#   2493   918    6.00885   52  354          -    6.00668      -  1147  372s
#   2548   920    6.04951   39  510          -    6.00670      -  1171  381s
#   2617   916    7.01383   42  248          -    6.00680      -  1195  388s
#   2669   905    8.01168   46  338          -    6.00688      -  1219  396s
#   2746   911    8.01025   48  225          -    6.00700      -  1243  406s
#   2837   901    6.01208   42  418          -    6.00708      -  1257  414s
#   2897   898    6.01062   42  406          -    6.00717      -  1280  423s
#   2977   881 infeasible   49               -    6.00726      -  1310  431s
#   3061   877    7.01150   47  239          -    6.00754      -  1332  440s
#   3159   868    6.00835   45  444          -    6.00770      -  1350  451s
#   3249   841    7.00887   44  205          -    6.00776      -  1380  462s
#   3350   821    7.00891   42  481          -    6.00801      -  1407  474s
#   3458   798    7.00729   35  419          -    6.00813      -  1427  486s
#   3565   775    7.00786   46  655          -    6.00832      -  1454  497s
#   3681   757    7.01038   50  564          -    6.00850      -  1472  510s
#   3801   734    7.01212   52  486          -    6.00863      -  1491  522s
#   3923   708    6.01277   44  581          -    6.00885      -  1510  535s
#   4047   664 infeasible   42               -    6.00900      -  1526  547s
#   4151   650 infeasible   48               -    6.00962      -  1546  559s
#   4260   626    7.01016   44  474          -    6.00996      -  1564  574s
#   4361   633    8.01495   36  328          -    6.01180      -  1591  587s
#   4478   626    8.01041   40  416          -    6.01240      -  1606  602s
#   4643   642 infeasible   35               -    6.03119      -  1611  617s
#   4769   654 infeasible   43               -    6.07246      -  1604  633s
#   4937   666    8.00975   47  100          -    7.00302      -  1611  648s
#   5063   693 infeasible   45               -    7.00440      -  1625  664s
#   5190   730 infeasible   50               -    7.00513      -  1638  682s
#   5338   760 infeasible   47               -    7.00525      -  1652  702s
#   5513   789    7.00950   39  300          -    7.00566      -  1662  721s
#   5702   834    7.00807   45  582          -    7.00592      -  1671  743s
#   5923   835    8.01369   56  437          -    7.00614      -  1673  775s
#   5962   864 infeasible   59               -    7.00615      -  1676  799s
#   6192   917    8.01112   45  129          -    7.00661      -  1685  826s
#   6462   951    7.00999   41  436          -    7.00694      -  1690  855s
#   6749   971    7.00877   47  606          -    7.00714      -  1700  884s
#   7079   992    8.01037   49  199          -    7.00746      -  1697  914s
#   7374  1001 infeasible   47               -    7.00797      -  1704  945s
# * 7611   977              41       8.0160000    7.00800  12.6%  1703  945s
#   7713   998 infeasible   55         8.01600    7.00829  12.6%  1707  976s
#   8305   996    8.01286   48  496    8.01600    7.00900  12.6%  1659 1012s
#   8921   993    7.26330   41  470    8.01600    7.00950  12.6%  1620 1047s
#   9546  1001    8.01133   45  203    8.01600    7.01039  12.5%  1583 1081s
#  10216   943    7.01401   44  430    8.01600    7.01142  12.5%  1546 1115s
#  10934  1027    8.01471   50  352    8.01600    7.01500  12.5%  1510 1146s
# *11464   292              46       7.0160000    7.01600  0.00%  1476 1146s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 35
#   Implied bound: 213
#   Clique: 66
#   Flow cover: 12
#   Zero half: 81
#   RLT: 6
#   Relax-and-lift: 64
#
# Explored 11616 nodes (17040502 simplex iterations) in 1146.84 seconds (1202.45 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7.016 8.016
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.016000000000e+00, best bound 7.016000000000e+00, gap 0.0000%
# time period 0
# |  4  5  2 |
# |  3  6  0 |
# |  7  0  1 |
#
# 機器人1在 [(3, 3)], 正在搬運貨物1
# 機器人2在 [(1, 3)], 正在搬運貨物2
# 機器人3在 [(2, 1)], 正在搬運貨物3
# 機器人4在 [(1, 1)]
# 機器人5在 [(1, 2)], 正在搬運貨物5
# 機器人6在 [(2, 2)], 正在搬運貨物6
# 機器人7在 [(3, 1)], 正在搬運貨物7
# 貨物1在 [(3, 3)]
# 貨物2在 [(1, 3)]
# 貨物3在 [(2, 1)]
# 貨物4在 [(1, 1)] (無固定目標位置)
# 貨物5在 [(1, 2)] (無固定目標位置)
# 貨物6在 [(2, 2)] (無固定目標位置)
# 貨物7在 [(3, 1)] (無固定目標位置)
#
# time period 1
# |  4  5  2 |
# |  0  3  6 |
# |  7  0  1 |
#
# 機器人1在 [(3, 3)]
# 機器人2在 [(1, 3)]
# 機器人3在 [(2, 2)], 正在搬運貨物3
# 機器人4在 [(1, 1)], 正在搬運貨物4
# 機器人5在 [(1, 2)], 正在搬運貨物5
# 機器人6在 [(2, 3)], 正在搬運貨物6
# 機器人7在 [(3, 1)], 正在搬運貨物7
# 貨物1在 [(3, 3)]
# 貨物2在 [(1, 3)]
# 貨物3在 [(2, 2)]
# 貨物4在 [(1, 1)] (無固定目標位置)
# 貨物5在 [(1, 2)] (無固定目標位置)
# 貨物6在 [(2, 3)] (無固定目標位置)
# 貨物7在 [(3, 1)] (無固定目標位置)
#
# time period 2
# |  0  5  2 |
# |  4  3  6 |
# |  7  0  1 |
#
# 機器人1在 [(3, 3)]
# 機器人2在 [(1, 3)], 正在搬運貨物2
# 機器人3在 [(2, 2)], 正在搬運貨物3
# 機器人4在 [(2, 1)], 正在搬運貨物4
# 機器人5在 [(1, 2)], 正在搬運貨物5
# 機器人6在 [(2, 3)]
# 機器人7在 [(3, 1)], 正在搬運貨物7
# 貨物1在 [(3, 3)]
# 貨物2在 [(1, 3)]
# 貨物3在 [(2, 2)]
# 貨物4在 [(2, 1)] (無固定目標位置)
# 貨物5在 [(1, 2)] (無固定目標位置)
# 貨物6在 [(2, 3)] (無固定目標位置)
# 貨物7在 [(3, 1)] (無固定目標位置)
#
# time period 3
# |  5  2  0 |
# |  4  0  6 |
# |  7  3  1 |
#
# 機器人1在 [(3, 3)], 正在搬運貨物1
# 機器人2在 [(1, 2)], 正在搬運貨物2
# 機器人3在 [(3, 2)], 正在搬運貨物3
# 機器人4在 [(2, 1)]
# 機器人5在 [(1, 1)]
# 機器人6在 [(2, 3)], 正在搬運貨物6
# 機器人7在 [(3, 1)]
# 貨物1在 [(3, 3)]
# 貨物2在 [(1, 2)]
# 貨物3在 [(3, 2)]
# 貨物4在 [(2, 1)] (無固定目標位置)
# 貨物5在 [(1, 1)] (無固定目標位置)
# 貨物6在 [(2, 3)] (無固定目標位置)
# 貨物7在 [(3, 1)] (無固定目標位置)
#
# time period 4
# |  5  2  6 |
# |  4  0  1 |
# |  7  3  0 |
#
# 機器人1在 [(2, 3)]
# 機器人2在 [(1, 2)], 正在搬運貨物2
# 機器人3在 [(3, 2)], 正在搬運貨物3
# 機器人4在 [(2, 1)]
# 機器人5在 [(1, 1)]
# 機器人6在 [(1, 3)]
# 機器人7在 [(3, 1)], 正在搬運貨物7
# 貨物1在 [(2, 3)]
# 貨物2在 [(1, 2)]
# 貨物3在 [(3, 2)]
# 貨物4在 [(2, 1)] (無固定目標位置)
# 貨物5在 [(1, 1)] (無固定目標位置)
# 貨物6在 [(1, 3)] (無固定目標位置)
# 貨物7在 [(3, 1)] (無固定目標位置)
#
# time period 5
# |  5  0  6 |
# |  4  2  1 |
# |  0  7  3 |
#
# 機器人1在 [(2, 3)], 正在搬運貨物1
# 機器人2在 [(2, 2)]
# 機器人3在 [(3, 3)]
# 機器人4在 [(2, 1)], 正在搬運貨物4
# 機器人5在 [(1, 1)]
# 機器人6在 [(1, 3)], 正在搬運貨物6
# 機器人7在 [(3, 2)]
# 貨物1在 [(2, 3)]
# 貨物2在 [(2, 2)]
# 貨物3在 [(3, 3)]
# 貨物4在 [(2, 1)] (無固定目標位置)
# 貨物5在 [(1, 1)] (無固定目標位置)
# 貨物6在 [(1, 3)] (無固定目標位置)
# 貨物7在 [(3, 2)] (無固定目標位置)
#
# time period 6
# |  5  6  0 |
# |  0  2  1 |
# |  4  7  3 |
#
# 機器人1在 [(2, 3)], 正在搬運貨物1
# 機器人2在 [(2, 2)], 正在搬運貨物2
# 機器人3在 [(3, 3)], 正在搬運貨物3
# 機器人4在 [(3, 1)]
# 機器人5在 [(1, 1)]
# 機器人6在 [(1, 2)], 正在搬運貨物6
# 機器人7在 [(3, 2)]
# 貨物1在 [(2, 3)]
# 貨物2在 [(2, 2)]
# 貨物3在 [(3, 3)]
# 貨物4在 [(3, 1)] (無固定目標位置)
# 貨物5在 [(1, 1)] (無固定目標位置)
# 貨物6在 [(1, 2)] (無固定目標位置)
# 貨物7在 [(3, 2)] (無固定目標位置)
#
# time period 7
# |  5  6  1 |
# |  2  0  3 |
# |  4  7  0 |
#
# 機器人1在 [(1, 3)]
# 機器人2在 [(2, 1)]
# 機器人3在 [(2, 3)]
# 機器人4在 [(3, 1)]
# 機器人5在 [(1, 1)]
# 機器人6在 [(1, 2)]
# 機器人7在 [(3, 2)]
# 貨物1在 [(1, 3)], 貨物已到達目標位置
# 貨物2在 [(2, 1)], 貨物已到達目標位置
# 貨物3在 [(2, 3)], 貨物已到達目標位置
# 貨物4在 [(3, 1)] (無固定目標位置)
# 貨物5在 [(1, 1)] (無固定目標位置)
# 貨物6在 [(1, 2)] (無固定目標位置)
# 貨物7在 [(3, 2)] (無固定目標位置)
#
# time period 8
# |  5  6  1 |
# |  2  0  3 |
# |  4  7  0 |
#
# 機器人1在 [(1, 3)]
# 機器人2在 [(2, 1)]
# 機器人3在 [(2, 3)]
# 機器人4在 [(3, 1)]
# 機器人5在 [(1, 1)]
# 機器人6在 [(1, 2)]
# 機器人7在 [(3, 2)]
# 貨物1在 [(1, 3)], 貨物已到達目標位置
# 貨物2在 [(2, 1)], 貨物已到達目標位置
# 貨物3在 [(2, 3)], 貨物已到達目標位置
# 貨物4在 [(3, 1)] (無固定目標位置)
# 貨物5在 [(1, 1)] (無固定目標位置)
# 貨物6在 [(1, 2)] (無固定目標位置)
# 貨物7在 [(3, 2)] (無固定目標位置)
